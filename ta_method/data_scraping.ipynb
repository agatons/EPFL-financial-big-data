# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
tickers = pd.read_csv('../data/raw/ticker_data.csv').rename(columns={'Ticker symbol' : 'ticker'})
print(tickers.shape)
print(len(tickers.ticker.unique()))
tickers_str_modified = ""
for ticker in tickers.ticker.values:
    if (ticker.endswith('.B')):
        tickers_str_modified += (ticker[0:-2] + '-B.ST ')
    elif (ticker.endswith('.A')):
        tickers_str_modified += (ticker[0:-2] + '-A.ST ')
    else:
        tickers_str_modified += (ticker + '.ST ')

tickers_str_modified
# Out:
# (607, 1)
# 607
# ...

# %%
data = yf.download(  
        # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = tickers_str_modified,

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "10y",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
data
# Out:
# [*********************100%***********************]  609 of 609 completed
#
# 33 Failed downloads:
# - MAHA: No data found, symbol may be delisted
# - MIC.SDB.ST: No data found, symbol may be delisted
# - A.ST: No data found, symbol may be delisted
# - SPIFFX.ST: No data found, symbol may be delisted
# - HDW: No data found for this date range, symbol may be delisted
# - A1M.ST: No data found, symbol may be delisted
# - THQN-B.ST: No data found, symbol may be delisted
# - PHLOG.ST: No data found, symbol may be delisted
# - HUBR-B.ST: No data found, symbol may be delisted
# - VNV.SDB.ST: No data found, symbol may be delisted
# - B3IT.ST: No data found for this date range, symbol may be delisted
# - CLX.ST: No data found for this date range, symbol may be delisted
# - ITAL.SDB.ST: No data found, symbol may be delisted
# - SEAB-B.ST: No data found, symbol may be delisted
# - ABFAST.ST: No data found for this date range, symbol may be delisted
# ...

# %%
data.to_pickle('../data/raw/swedish_stocks')
